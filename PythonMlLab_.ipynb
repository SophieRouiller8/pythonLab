# %% [markdown]
# # Import our own files

# %%
# mount goole drive to acces the config files
from google.colab import drive
drive.mount('/content/gdrive')

# %%
#cd to the config file
# %cd '/content/gdrive/MyDrive/Colab Notebooks'

# %%
# import config file from local computer
from myconfig import NAME

# %% [markdown]
# # List comprehension

# %%
# create a list of squared paire element in range 0 to 10 using list comprehension
anotherlist=[i*i for i in range(0,10) if i%2==0]

# %%
# create a list of squared paire element in range 0 to 10 using for loop
my_list=[]
for i in range(0,10):
  if i%2==0:
    my_list.append(i*i)
